# %% [markdown]
# <div class="alert alert-block alert-info" align="center" style="padding: 10px;">
#     <h1><b><u>Feature Engineering-2</u></b></h1>
# </div>
#
# ### **Q1. What is the Filter method in feature selection, and how does it work?** ###
#
# The Filter method in feature selection is a technique used to select relevant features from a dataset based on their statistical properties or some other measure of importance. It works by independently evaluating each feature and assigning a score or ranking to them. Features are then selected or ranked based on these scores, and a subset of the most relevant features is chosen for model training.
#
# ---
#
# ### **Q2. How does the Wrapper method differ from the Filter method in feature selection?** ###
#
# It evaluates feature subsets by considering the performance of a machine learning model. It involves creating multiple subsets of features and training a model with each subset. The performance of the model (e.g., accuracy, F1 score) is then used to determine which feature subset is the best. This method is computationally more intensive compared to the Filter method.
#
# ---
#
# ### **Q3. What are some common techniques used in Embedded feature selection methods?**
#
# **Embedded feature selection methods include techniques such as:**
# 1. L1 regularization (Lasso regression)
# 2. Decision tree-based algorithms like Random Forest or XGBoost
#
# ---
#
# ### **Q4. What are some drawbacks of using the Filter method for feature selection?**
#
# **Drawbacks of using the Filter method for feature selection:**
# 1. Ignores feature interactions.
# 2. May select redundant features.
# 3. Scoring metric choice can be subjective.
# 4. Doesn't consider the specific model's needs.
#
# ---
#
# ### **Q5. In which situations would you prefer using the Filter method over the Wrapper method for feature selection?**
#
# **We use the Filter method over the Wrapper method for feature selection in situations where:**
# 1. Computational resources are limited.
# 2. You need a rapid and efficient feature selection process.
# 3. You want to get an initial understanding of feature relevance without exhaustively testing feature subsets.
#
# ---
#
# ### **Q6. In a telecom company, you are working on a project to develop a predictive model for customer churn. You are unsure of which features to include in the model because the dataset contains several different ones. Describe how you would choose the most pertinent attributes for the model using the Filter Method.**
#
# **You would follow these steps:**
# 1. Calculate a relevance score for each feature using a suitable metric with the target variable.
# 2. Rank features based on their relevance scores.
# 3. Select the top N features with the highest scores.
# 4. Use the selected features to train your predictive model for customer churn.
#
# ---
#
# ### **Q7. You are working on a project to predict the outcome of a soccer match. You have a large dataset with many features, including player statistics and team rankings. Explain how you would use the Embedded method to select the most relevant features for the model.**
#
# **To use the Embedded method to select the most relevant features for predicting the outcome of a soccer match, follow these steps:**
# 1. Choose a machine learning algorithm suitable for the prediction task, such as a random forest or gradient boosting model.
# 2. Train the model on the entire dataset, including all features.
# 3. Extract feature importances from the trained model.
# 4. Rank or sort the features based on their importances.
# 5. Select the top N features.
# 6. Use this selected subset of features to build your predictive model for soccer match outcomes.
#
# ---
#
# ### **Q8. You are working on a project to predict the price of a house based on its features, such as size, location, and age. You have a limited number of features, and you want to ensure that you select the most important ones for the model. Explain how you would use the Wrapper method to select the best set of features for the predictor.**
#
# **Follow these steps:**
# 1. Start with an initial feature subset.
# 2. Train a machine learning model using this feature subset and evaluate its performance using a suitable metric.
# 3. Iteratively add or remove features from the subset and retrain the model performance at each step.
# 4. Use a search strategy to explore different feature combinations.
# 5. Stop the search when you find the best-performing feature subset based on the chosen evaluation metric.
# 6. Use the selected subset of features to build your final predictive model for house prices.
